# %%
import matplotlib.pyplot as plt
import numpy as np 
import math as m
import cmath as cm

# %%
def x(t):
    if (t<0):
        return 0
    else:
        return np.exp(-t)
print(x(1*0.25))
# Out:
# 0.7788007830714049

# %%
N=32
f=np.linspace(-2,2,N)
n=np.linspace(0,31,N)  #ndT=t
dT=0.25

fs=1/dT
xsample=np.zeros(N)
for i in range(0,N):
    xsample[i]=x(n[i]*dT)

# %%
    Xf=[]
    for ii in f:
        S=0
        for i in range(0,31):
            S+= x(i*dT)*np.exp(-1j*2*np.pi*i*ii*dT)
            
        Xf.append(S)      
    X1 = np.conjugate(Xf)
    X2 = Xf*X1
    X3 = np.sqrt(X2)
print(len(X3))
# Out:
# 32

# %%
plt.plot(f,X3)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
def func(ff):
    return (1/np.sqrt(1+(4*np.pi**2*ff**2)))

# %%
Xi=[]
for i in f:
    Xi.append(func(i))

# %%
print(len(Xi))
# Out:
# 32

# %%
plt.plot(f,Xi)

# %%
#Final
f=np.linspace(-2,2,32)
fs=4
n=np.linspace(0,31,32)
dT=0.25
x=np.exp(-n*dT)
N=32

# %%
def X(f,x,fs):
    N=len(x)
    indices=np.arange(N)
    exponentials=np.exp(-2*1j*np.pi*(f/fs)*indices)
    return abs(np.sum(x*exponentials))

# %%
Xf=[]
for i in f:
    Xf.append(X(i,x,fs))

# %%
plt.plot(f,Xf)
plt.plot(f,X3)
